# %% [markdown]
# ##Multi_Regression by (sklearn) and without (sklearn)

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes

# %% [markdown]
# ###Built_in_dataset

# %%
x,y = load_diabetes(return_X_y=True,as_frame=True)

# %%
y
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
print(x.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %% [markdown]
# ##Using Sklearn's Linear_Regression

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=4)

# %%
from  sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)

# %%
1 - ((1-r2)*(len(y_test)-1))/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.39200901457705606

# %%
model.coef_
# Out:
# array([  33.40954056, -292.24112825,  481.08002807,  369.05716136,
#        -966.32463944,  589.771093  ,  232.59825938,  288.32164654,
#         802.69901575,   37.81345763])

# %%
model.intercept_
# Out:
# np.float64(151.1466544656964)

# %% [markdown]
# ## Making our own Linear_Regression class

# %%
class my_lr:
  def __init__(self) -> None:
    self.coef_ = None
    self.intercept_ = None

  def fit(self,x_train,y_train):
    x_train = np.insert(x_train.values, 0, 1, axis=1)


    # calculate the coeficient
    betas = np.linalg.inv(np.dot(x_train.T,x_train)).dot(x_train.T).dot(y_train)
    self.intercept_ = betas[0]
    self.coef_ = betas[1:]

  def prediction(self,x_test):
    y_pred = np.dot(x_test,self.coef_) + self.intercept_
    return y_pred

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
obj = my_lr()

# %%
obj.fit(x_train,y_train)

# %%
obj.prediction(x_test)
# Out:
# array([ 74.43280315,  93.01188422, 174.89583708,  52.70477804,
#        180.6344672 , 145.29489212, 112.87543999, 121.31739633,
#         86.80055781,  72.09487051, 106.45282573, 193.85987207,
#        182.28344544, 125.44811935, 155.8896893 , 139.16031299,
#        176.97501885, 119.39134941, 110.71759865, 183.79817912,
#        215.37006731, 181.15425179,  58.74452494, 228.82182365,
#         54.20964003, 107.86930863, 157.15782778, 180.13351581,
#         62.2029307 ,  67.18271285, 190.82019192, 118.09294588,
#        260.8951241 , 183.19776479, 105.61124665, 175.91603519,
#        176.89309477, 156.04689432, 146.92759805, 157.34037113,
#        198.17713428, 168.03067448, 237.98412043,  71.34000677,
#        237.44866784, 108.06983532, 152.11844679,  50.31084484,
#        199.55707357, 139.53035368, 110.45552956, 101.51968242,
#        154.91473627, 228.90111686,  54.52296474, 187.29195473,
#        106.15268895,  93.61822132, 190.00645205, 226.39902673,
# ...

# %%
print("intercept: ",obj.intercept_)
print("coeficient: ",obj.coef_)
# Out:
# intercept:  151.14665446569646
# coeficient:  [  33.40954056 -292.24112825  481.08002807  369.05716136 -966.32463944
#   589.771093    232.59825938  288.32164654  802.69901575   37.81345763]
